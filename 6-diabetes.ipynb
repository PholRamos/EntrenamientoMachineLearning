# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'e:\\SENATI\\PlanSesion20204-1\\ING-SOFT-SEMESTRE-IV\\1-ALGORITMOS-IA\\AlgoritmosIA'

# %%
ls
# Out:
#  El volumen de la unidad E es BlueDisk
#  El n�mero de serie del volumen es: B4B5-099C
#
#  Directorio de e:\SENATI\PlanSesion20204-1\ING-SOFT-SEMESTRE-IV\1-ALGORITMOS-IA\AlgoritmosIA
#
# 23/02/2024  12:18    <DIR>          .
# 23/02/2024  12:18    <DIR>          ..
# 22/02/2024  21:36             9,128 DataSetDiabetes.zip
# 22/02/2024  21:40            23,876 diabetes.csv
# 23/02/2024  10:51           252,231 diabetes.ipynb
# 16/02/2024  11:52                60 Ejemplo_excel.csv
# 16/02/2024  11:04             5,508 Ejemplo_excel.xlsx
# 22/02/2024  10:28           268,626 matplotlib.ipynb
# 16/02/2024  10:55                19 Modelo1.py
# 16/02/2024  10:55            22,530 numpy.ipynb
# 16/02/2024  13:41           794,894 pandas.ipynb
# 22/02/2024  23:03           251,588 Predicciondiabetes.ipynb
# 16/02/2024  10:55           114,171 PrimerModelo.ipynb
# 23/02/2024  11:04           178,368 regresionLogistica.ipynb
# 16/02/2024  12:13             5,087 salida_excel_py.xlsx
# ...

# %%
diabetes = pd.read_csv('diabetes.csv')

# %%
diabetes
# Out:
#      Embarazos  Glucosa  Presionarterial  EspesorPiel  Insulina   BMI  \
# 0            6      148               72           35         0  33.6
# 1            1       85               66           29         0  26.6
# 2            8      183               64            0         0  23.3
# 3            1       89               66           23        94  28.1
# 4            0      137               40           35       168  43.1
# ..         ...      ...              ...          ...       ...   ...
# 763         10      101               76           48       180  32.9
# 764          2      122               70           27         0  36.8
# 765          5      121               72           23       112  26.2
# 766          1      126               60            0         0  30.1
# 767          1       93               70           31         0  30.4
#
#      DiabetesPedigreeFunction  Age  Resultado
# 0                       0.627   50          1
# ...

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Embarazos                 768 non-null    int64
#  1   Glucosa                   768 non-null    int64
#  2   Presionarterial           768 non-null    int64
#  3   EspesorPiel               768 non-null    int64
#  4   Insulina                  768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Resultado                 768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.describe()
# Out:
#         Embarazos     Glucosa  Presionarterial  EspesorPiel    Insulina  \
# count  768.000000  768.000000       768.000000   768.000000  768.000000
# mean     3.845052  120.894531        69.105469    20.536458   79.799479
# std      3.369578   31.972618        19.355807    15.952218  115.244002
# min      0.000000    0.000000         0.000000     0.000000    0.000000
# 25%      1.000000   99.000000        62.000000     0.000000    0.000000
# 50%      3.000000  117.000000        72.000000    23.000000   30.500000
# 75%      6.000000  140.250000        80.000000    32.000000  127.250000
# max     17.000000  199.000000       122.000000    99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age   Resultado
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes.columns
# Out:
# Index(['Embarazos', 'Glucosa', 'Presionarterial', 'EspesorPiel', 'Insulina',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Resultado'],
#       dtype='object')

# %%
diabetes['Glucosa']
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucosa, Length: 768, dtype: int64

# %%
sns.displot(diabetes['Resultado'])

# %%
correlacion = diabetes.corr()
sns.heatmap(correlacion,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
diabetes.head()
# Out:
#    Embarazos  Glucosa  Presionarterial  EspesorPiel  Insulina   BMI  \
# 0          6      148               72           35         0  33.6
# 1          1       85               66           29         0  26.6
# 2          8      183               64            0         0  23.3
# 3          1       89               66           23        94  28.1
# 4          0      137               40           35       168  43.1
#
#    DiabetesPedigreeFunction  Age  Resultado
# 0                     0.627   50          1
# 1                     0.351   31          0
# 2                     0.672   32          1
# 3                     0.167   21          0
# 4                     2.288   33          1

# %%
diabetes.columns
# Out:
# Index(['Embarazos', 'Glucosa', 'Presionarterial', 'EspesorPiel', 'Insulina',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Resultado'],
#       dtype='object')

# %%
X=diabetes[['Embarazos', 'Glucosa', 'Presionarterial', 'EspesorPiel', 'Insulina',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]

# %%
X
# Out:
#      Embarazos  Glucosa  Presionarterial  EspesorPiel  Insulina   BMI  \
# 0            6      148               72           35         0  33.6
# 1            1       85               66           29         0  26.6
# 2            8      183               64            0         0  23.3
# 3            1       89               66           23        94  28.1
# 4            0      137               40           35       168  43.1
# ..         ...      ...              ...          ...       ...   ...
# 763         10      101               76           48       180  32.9
# 764          2      122               70           27         0  36.8
# 765          5      121               72           23       112  26.2
# 766          1      126               60            0         0  30.1
# 767          1       93               70           31         0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=diabetes[['Resultado']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=10)

# %%
X_test
# Out:
#      Embarazos  Glucosa  Presionarterial  EspesorPiel  Insulina   BMI  \
# 568          4      154               72           29       126  31.3
# 620          2      112               86           42       160  38.4
# 456          1      135               54            0         0  26.7
# 197          3      107               62           13        48  22.9
# 714          3      102               74            0         0  29.5
# ..         ...      ...              ...          ...       ...   ...
# 264          4      123               62            0         0  32.0
# 706         10      115                0            0         0   0.0
# 194          8       85               55           20         0  24.4
# 179          5      130               82            0         0  39.1
# 514          3       99               54           19        86  25.6
#
#      DiabetesPedigreeFunction  Age
# 568                     0.338   37
# 620                     0.246   28
# ...

# %%
y_test
# Out:
#      Resultado
# 568          0
# 620          0
# 456          0
# 197          1
# 714          0
# ..         ...
# 264          1
# 706          1
# 194          0
# 179          1
# 514          0
#
# [154 rows x 1 columns]

# %%
entrenamiento = LinearRegression()
entrenamiento.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
prediccion = entrenamiento.predict(X_test)

# %%
prediccion
# Out:
# array([[ 0.53060482],
#        [ 0.2575757 ],
#        [ 0.49635077],
#        [ 0.1405268 ],
#        [ 0.11877309],
#        [ 0.00240965],
#        [ 0.09789438],
#        [ 0.36205851],
#        [ 0.05629985],
#        [ 0.4121684 ],
#        [ 0.07633124],
#        [ 0.3100039 ],
#        [ 0.86403605],
#        [ 0.36653835],
#        [ 0.13905379],
#        [ 0.64740308],
#        [ 0.70102572],
#        [-0.01143402],
#        [ 0.12168798],
#        [ 0.91709782],
#        [ 0.38264279],
#        [ 0.49367882],
#        [ 0.39203768],
#        [ 0.30719499],
#        [ 0.22751542],
#        [ 0.60006475],
#        [ 0.33696475],
#        [-0.25031547],
#        [ 0.58442376],
#        [ 0.74456138],
#        [ 0.29124668],
#        [-0.02637417],
#        [ 0.0790899 ],
#        [ 0.17765737],
#        [ 0.41731491],
#        [ 0.17352556],
#        [ 0.3418467 ],
#        [ 0.32755713],
#        [ 0.63298291],
#        [ 0.03677712],
#        [ 0.44912568],
# ...

# %%
diabetes.loc[620]
# Out:
# Embarazos                     2.000
# Glucosa                     112.000
# Presionarterial              86.000
# EspesorPiel                  42.000
# Insulina                    160.000
# BMI                          38.400
# DiabetesPedigreeFunction      0.246
# Age                          28.000
# Resultado                     0.000
# Name: 620, dtype: float64

# %%
X_test
# Out:
#      Embarazos  Glucosa  Presionarterial  EspesorPiel  Insulina   BMI  \
# 568          4      154               72           29       126  31.3
# 620          2      112               86           42       160  38.4
# 456          1      135               54            0         0  26.7
# 197          3      107               62           13        48  22.9
# 714          3      102               74            0         0  29.5
# ..         ...      ...              ...          ...       ...   ...
# 264          4      123               62            0         0  32.0
# 706         10      115                0            0         0   0.0
# 194          8       85               55           20         0  24.4
# 179          5      130               82            0         0  39.1
# 514          3       99               54           19        86  25.6
#
#      DiabetesPedigreeFunction  Age
# 568                     0.338   37
# 620                     0.246   28
# ...

# %%
Embarazos=int(input("Ingrese el numero de embarazos"))
Glucosa=int(input("Ingrese Glucosa"))
Presionarterial=int(input("Ingrese Presion arterial"))
EspesorPiel=int(input("Ingrese Espesor de la piel"))
Insulina=int(input("Ingrese insulina"))
BMI=float(input("Ingrese Masa Corporal"))
DiabetesPedigreeFunction=float(input("Ingrese DPF"))
Age=int(input("Ingrese la edad"))

# %%
nuevos_datos= pd.DataFrame({
    "Embarazos":[Embarazos],
    "Glucosa":[Glucosa],
    "Presionarterial":[Presionarterial],
    "EspesorPiel":[EspesorPiel],
    "Insulina":[Insulina],
    "BMI":[BMI],
    "DiabetesPedigreeFunction":[DiabetesPedigreeFunction],
    "Age":[Age]
})

# %%
nuevos_datos
# Out:
#    Embarazos  Glucosa  Presionarterial  EspesorPiel  Insulina   BMI  \
# 0          0      100               70           20         0  22.0
#
#    DiabetesPedigreeFunction  Age
# 0                      0.01   30

# %%
prediccion=entrenamiento.predict(nuevos_datos)

# %%
print("El resultado del diagnostico es: ",prediccion)
# Out:
# El resultado del diagnostico es:  [[0.00105615]]

# %%
sns.heatmap(diabetes.isnull())
# Out:
# <Axes: >
